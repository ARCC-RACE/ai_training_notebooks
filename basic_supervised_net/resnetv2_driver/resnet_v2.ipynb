# %% [markdown]
# # Jetsoncar Resnet V2
#
# Tensorflow 2.0, all in notebook, optimized with RT. V2 includes depth image

# %%
import tensorflow as tf
print(tf.__version__)
tf.config.experimental.list_physical_devices('GPU') # If device does not show and using conda env with tensorflow-gpu then try restarting computer
# Out:
# 2.1.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# verify the image data directory
import os
data_directory = "/media/michael/BigMemory/datasets/jetsoncar/training_data/data/dataset"
os.listdir(data_directory)[:10]

import matplotlib.pyplot as plt
img = plt.imread(os.path.join(data_directory + "/color_images", os.listdir(data_directory + "/color_images")[0]))
print(img.shape)
plt.imshow(img)
plt.show()

img = plt.imread(os.path.join(data_directory + "/depth_images", os.listdir(data_directory + "/color_images")[0]))
plt.imshow(img)
plt.show()
# Out:
# (480, 848, 3)

# %% [markdown]
# ## Create the datagenerator and augmentation framework

# %%
# Include the custom utils.py and perform tests
# Include the custom utils.py and perform tests
import importlib, os, sys
import numpy as np

package_name = os.path.basename(os.getcwd())
print(package_name)
print(os.getcwd())
sys.path.append(os.getcwd())
import utils


print(utils.INPUT_SHAPE)

img = utils.load_image(os.path.join(data_directory, 'color_images'),os.listdir(data_directory + "/color_images")[0])
depth_img = utils.load_image(os.path.join(data_directory, 'depth_images'),os.listdir(data_directory + "/depth_images")[0])

print(img.shape)
print(depth_img.shape)

fig = plt.figure(figsize=(20,20))
fig.add_subplot(1, 3, 1)
plt.imshow(img)

img, _ = utils.preprocess_data(last_color_image=img, last_depth_image=depth_img)
print(img[0].shape)
print(img[1].shape)

fig.add_subplot(1, 3, 2)
plt.imshow(np.squeeze(img[0]))

fig.add_subplot(1, 3, 3)
plt.imshow(np.squeeze(img[1]))

plt.show()
# Out:
# resnetv2_driver
# /home/michael/Github/ai_training_notebooks/basic_supervised_net/resnetv2_driver
# (240, 640, 3)
# (480, 848, 3)
# (480, 848)
# (240, 640, 3)
# (240, 640)

# %%
# Load the steering angles and image paths from labels.csv
import csv, random
import seaborn as sns

# these will be 2D arrays where each row represents a dataset
x = [] # images
y = [] # steering
z = [] # speed
with open(os.path.join(data_directory, "tags.csv")) as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # print(row['Time_stamp'] + ".jpg", row['Steering_angle'])
        if not float(row['raw_speed']) == 0:
            x.append(row['time_stamp'] + ".jpg",)  # get image path
            y.append(float(row['raw_steering']),) # get steering value
            z.append(float(row['raw_speed']))

print("Number of data samples is " + str(len(y)))

data = list(zip(x,y))
random.shuffle(data)
x,y = zip(*data)

# plot of steering angle distribution without correction
sns.distplot(y)
# Out:
# Number of data samples is 17214

# %%
# plot of speed distribution
sns.distplot(z)

# %%
# Split the training data
validation_split = 0.2
train_x = x[0:int(len(x)*(1.0-validation_split))]
train_y = y[0:int(len(y)*(1.0-validation_split))]
print("Training data shape: " + str(len(train_x)))
test_x = x[int(len(x)*(1.0-validation_split)):]
test_y = y[int(len(y)*(1.0-validation_split)):]
print("Validation data shape: " + str(len(test_x)) + "\n")
# Out:
# Training data shape: 13771
# Validation data shape: 3443

# %%
# Define and test batch generator
def batch_generator(data_dir, image_paths, steering_angles, batch_size, is_training):
    """
    Generate training image give image paths and associated steering angles
    """
    color_images = np.empty([batch_size, utils.IMAGE_HEIGHT, utils.IMAGE_WIDTH, utils.IMAGE_CHANNELS])
    depth_images = np.empty([batch_size, utils.IMAGE_HEIGHT, utils.IMAGE_WIDTH])
    steers = np.empty(batch_size)
    while True:
        i = 0
        for index in np.random.permutation(len(image_paths)):
            img = image_paths[index]
            steering_angle = steering_angles[index]
            # argumentation
            if is_training and np.random.rand() < 0.8:
                image, steering_angle = utils.augument(data_dir, os.path.join("color_images",img), os.path.join("depth_images",img), steering_angle)
            else:
                image, _ = utils.preprocess_data(utils.load_image(data_dir, os.path.join("color_images",img)), utils.load_image(data_dir, os.path.join("depth_images",img)))
            # add the image and steering angle to the batch
            color_images[i] = image[0]
            depth_images[i] = image[1]                         
            steers[i] = steering_angle
            i += 1
            if i == batch_size:
                break
        yield [color_images, depth_images], steers
        
train_generator = batch_generator(data_directory, train_x, train_y, 16, True)
validation_generator = batch_generator(data_directory, test_x, test_y,16, False)

train_image = next(train_generator) # returns tuple with steering and throttle
print(train_image[0][0].shape)
print(train_image[0][1].shape)
print(train_image[1][0])
fig = plt.figure(figsize=(20,20))
fig.add_subplot(1,2,1)
plt.imshow(train_image[0][0][0])
fig.add_subplot(1,2,2)
plt.imshow(np.squeeze(train_image[0][1][0]))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (16, 240, 640, 3)
# (16, 240, 640, 1)
# 0.355755730324378

# %% [markdown]
# ## Define the model and start training

# %%
# This is a pretrained resnet50 with custom head for detection
resnet = tf.keras.applications.ResNet50V2(include_top=False, input_tensor=tf.keras.layers.Input(shape=(240, 640, 3))) # takes in image of 224x224
resnet_head = tf.keras.models.Model(inputs=resnet.input, outputs=resnet.layers[-46].output) # get output to (14x14x256)
# don't retrain weights from imagenet
# for layer in resnet_head.layers:
#     layer.trainable = False 
    
# resnet_head.summary()

# custom tail
x = tf.keras.layers.Conv2D(64, (3,3), kernel_initializer='lecun_uniform', padding='same')(resnet_head.output)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Conv2D(32, (3,3), kernel_initializer='lecun_uniform', padding='same')(resnet_head.output)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Conv2D(16, (3,3), kernel_initializer='lecun_uniform', padding='same')(resnet_head.output)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Conv2D(8, (3,3), kernel_initializer='lecun_uniform', padding='same')(resnet_head.output)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(10, activation='elu')(x)
resnet_out = tf.keras.layers.Dense(1, activation='linear')(x)

# Merge the models together to create nav_net
depth_in = tf.keras.Input(shape=(240, 640, 1))
x = tf.keras.layers.Conv2D(32, (7,7), kernel_initializer='lecun_uniform', padding='same')(depth_in)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Conv2D(32, (5,5), kernel_initializer='lecun_uniform', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Conv2D(16, (3,3), kernel_initializer='lecun_uniform', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
x = tf.keras.layers.Conv2D(8, (3,3), kernel_initializer='lecun_uniform', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Activation('elu')(x)
x = tf.keras.layers.MaxPool2D((2,2))(x)
depth_out = tf.keras.layers.Flatten()(x)


combined = tf.keras.layers.concatenate([resnet_out, depth_out])
x = tf.keras.layers.Dense(10, activation='elu')(combined)
out = tf.keras.layers.Dense(1, activation='linear')(x)

model = tf.keras.models.Model(inputs=[resnet_head.input, depth_in], outputs=out)
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 240, 640, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 246, 646, 3)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 120, 320, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 122, 322, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 60, 160, 64)  0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 60, 160, 64)  256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 60, 160, 64)  0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 60, 160, 64)  4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 60, 160, 64)  256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 60, 160, 64)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 62, 162, 64)  0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 60, 160, 64)  36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 60, 160, 64)  256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 60, 160, 64)  0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 60, 160, 256) 16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 60, 160, 256) 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 60, 160, 256) 0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 60, 160, 256) 1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 60, 160, 256) 0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 60, 160, 64)  16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 60, 160, 64)  256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 60, 160, 64)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 62, 162, 64)  0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 60, 160, 64)  36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 60, 160, 64)  256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 60, 160, 64)  0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 60, 160, 256) 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 60, 160, 256) 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 60, 160, 256) 1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 60, 160, 256) 0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 60, 160, 64)  16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 60, 160, 64)  256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 60, 160, 64)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 62, 162, 64)  0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 30, 80, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 30, 80, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 30, 80, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 30, 80, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 30, 80, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 30, 80, 256)  0           max_pooling2d_22[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 30, 80, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 30, 80, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 30, 80, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 30, 80, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 32, 82, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 30, 80, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 30, 80, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 30, 80, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 30, 80, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 30, 80, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 30, 80, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 30, 80, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 30, 80, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 30, 80, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 32, 82, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 30, 80, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 30, 80, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 30, 80, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 30, 80, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 30, 80, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 30, 80, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 30, 80, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 30, 80, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 32, 82, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 30, 80, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 30, 80, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 30, 80, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 30, 80, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 30, 80, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 30, 80, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 30, 80, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 30, 80, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 30, 80, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 32, 82, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 15, 40, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 15, 40, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 15, 40, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 15, 40, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 15, 40, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 15, 40, 512)  0           max_pooling2d_23[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 15, 40, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 15, 40, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 15, 40, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 15, 40, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 17, 42, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 15, 40, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 15, 40, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 15, 40, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 15, 40, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 15, 40, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 15, 40, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 15, 40, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 15, 40, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 15, 40, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 17, 42, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 15, 40, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 15, 40, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 15, 40, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 15, 40, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 15, 40, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 15, 40, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 15, 40, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 15, 40, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 17, 42, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 15, 40, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 15, 40, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 15, 40, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 15, 40, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 15, 40, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 15, 40, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 15, 40, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 15, 40, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 17, 42, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 15, 40, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 15, 40, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 15, 40, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 15, 40, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 15, 40, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 15, 40, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 15, 40, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 240, 640, 1) 0
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 15, 40, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 240, 640, 32) 1600        input_6[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 17, 42, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 240, 640, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 15, 40, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 240, 640, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 15, 40, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 120, 320, 32) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 15, 40, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 120, 320, 32) 25632       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 15, 40, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 120, 320, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 15, 40, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 120, 320, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 15, 40, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 60, 160, 32)  0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 15, 40, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 60, 160, 16)  4624        max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 15, 40, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 60, 160, 16)  64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 15, 40, 8)    18440       conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 60, 160, 16)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 15, 40, 8)    32          conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 30, 80, 16)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 15, 40, 8)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 30, 80, 8)    1160        max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 7, 20, 8)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 30, 80, 8)    32          conv2d_23[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 1120)         0           max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 30, 80, 8)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10)           11210       flatten_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 15, 40, 8)    0           activation_23[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            11          dense_8[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 4800)         0           max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4801)         0           dense_9[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 10)           48020       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            11          dense_10[0][0]
# ==================================================================================================
# Total params: 7,829,492
# Trainable params: 7,805,364
# Non-trainable params: 24,128
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, 'model.png')

# %%
import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
print("To view tensorboard please run `tensorboard --logdir logs/fit` in the code directory from the terminal with deeplearning env active")

checkpoint = tf.keras.callbacks.ModelCheckpoint('rosey_v2.{epoch:03d}-{val_loss:.2f}.h5', # filepath = working directory/
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    mode='auto')

model.fit_generator(train_generator,
                    steps_per_epoch=100, 
                    epochs=20,
                    validation_data=validation_generator,
                    validation_steps=1,
                   callbacks=[tensorboard_callback, checkpoint])
# Out:
# To view tensorboard please run `tensorboard --logdir logs/fit` in the code directory from the terminal with deeplearning env active
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 100 steps, validate for 1 steps
# Epoch 1/20
# 100/100 [==============================] - 100s 997ms/step - loss: 0.3091 - val_loss: 0.2279
# Epoch 2/20
# 100/100 [==============================] - 100s 1s/step - loss: 0.0699 - val_loss: 0.0417
# Epoch 3/20
# 100/100 [==============================] - 104s 1s/step - loss: 0.0467 - val_loss: 0.0337
# Epoch 4/20
# 100/100 [==============================] - 99s 994ms/step - loss: 0.0503 - val_loss: 0.0671
# Epoch 5/20
# 100/100 [==============================] - 101s 1s/step - loss: 0.0454 - val_loss: 0.0233
# Epoch 6/20
# 100/100 [==============================] - 97s 968ms/step - loss: 0.0447 - val_loss: 0.0263
# Epoch 7/20
# 100/100 [==============================] - 96s 958ms/step - loss: 0.0417 - val_loss: 0.0207
# Epoch 8/20
# 100/100 [==============================] - 95s 952ms/step - loss: 0.0392 - val_loss: 0.0357
# Epoch 9/20
# 100/100 [==============================] - 98s 975ms/step - loss: 0.0368 - val_loss: 0.0295
# Epoch 10/20
# 100/100 [==============================] - 96s 964ms/step - loss: 0.0415 - val_loss: 0.1851
# Epoch 11/20
# 100/100 [==============================] - 96s 959ms/step - loss: 0.0355 - val_loss: 0.0548
# Epoch 12/20
# 100/100 [==============================] - 102s 1s/step - loss: 0.0332 - val_loss: 0.1264
# Epoch 13/20
# 100/100 [==============================] - 94s 943ms/step - loss: 0.0304 - val_loss: 0.0259
# Epoch 14/20
# 100/100 [==============================] - 100s 997ms/step - loss: 0.0318 - val_loss: 0.0191
# Epoch 15/20
# 100/100 [==============================] - 97s 967ms/step - loss: 0.0420 - val_loss: 0.0223
# Epoch 16/20
# 100/100 [==============================] - 97s 972ms/step - loss: 0.0291 - val_loss: 0.1472
# Epoch 17/20
# 100/100 [==============================] - 97s 971ms/step - loss: 0.0330 - val_loss: 0.0486
# Epoch 18/20
# 100/100 [==============================] - 97s 971ms/step - loss: 0.0310 - val_loss: 0.0479
# Epoch 19/20
# 100/100 [==============================] - 101s 1s/step - loss: 0.0348 - val_loss: 0.1585
# Epoch 20/20
#  54/100 [===============>..............] - ETA: 45s - loss: 0.0322

# %%
# Test the model
image, steering = next(train_generator)
print(steering)
print(model.predict(image))
print("")

image, steering = next(validation_generator)
print(steering)
print(model.predict(image))

# %% [markdown]
# ## Save the model as tensor RT and export to Jetson format

# %%
# Load the model that you would like converted to RT
model_path = 'model.h5'
export_path = "/home/michael/Desktop/model"

import shutil
if not os.path.isdir(export_path):
    os.mkdir(export_path)
else:
    response = input("Do you want to delete existing export_path directory? y/n")
    if response == 'y':
        shutil.rmtree(export_path)
        os.mkdir(export_path)

loaded_model = tf.keras.models.load_model(model_path)

shutil.copy("./utils.py", os.path.join(export_path, "utils.py"))
shutil.copy("./__init__.py", os.path.join(export_path, "__init__.py"))
shutil.copy("./notes.txt", os.path.join(export_path, "notes.txt"))
shutil.copy("./config.yaml", os.path.join(export_path, "config.yaml"))
# Save as tf saved_model (faster than h5)
tf.saved_model.save(loaded_model, export_path)
# Out:
# Do you want to delete existing export_path directory? y/n y
# WARNING:tensorflow:From /home/michael/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /home/michael/Desktop/model/assets

# %%
from tensorflow.python.compiler.tensorrt import trt_convert as trt

conversion_params = trt.DEFAULT_TRT_CONVERSION_PARAMS
conversion_params = conversion_params._replace(max_workspace_size_bytes=(1 << 32))
conversion_params = conversion_params._replace(precision_mode="INT8")
conversion_params = conversion_params._replace(maximum_cached_engines=100)
conversion_params = conversion_params._replace(use_calibration=True)

def my_calibration_input_fn():
    for i in range(20):
        image, _ = utils.preprocess_data(utils.load_image(data_directory, os.path.join("color_images",x[i])))
        yield image.astype(np.float32),

converter = trt.TrtGraphConverterV2(input_saved_model_dir=export_path,conversion_params=conversion_params)

gen = my_calibration_input_fn()

converter.convert(calibration_input_fn=my_calibration_input_fn)
converter.build(my_calibration_input_fn)

if not os.path.isdir(os.path.join(export_path, "rt")):
    os.mkdir(os.path.join(export_path, "rt"))
    
converter.save(os.path.join(export_path, "rt"))
# Out:
# INFO:tensorflow:Linked TensorRT version: (0, 0, 0)
# INFO:tensorflow:Loaded TensorRT version: (0, 0, 0)
# INFO:tensorflow:Running against TensorRT version 0.0.0
# INFO:tensorflow:Assets written to: /home/michael/Desktop/model/rt/assets

# %%
# Test normal saved model
saved_model = tf.saved_model.load(export_path) # normal saved model

image, _ = next(validation_generator)

import time
output = saved_model(image.astype(np.float32)) # load once to get more accurate representation of speed
start = time.time()
output = saved_model(image.astype(np.float32))
stop = time.time()
print("inference time: " + str(stop - start))
print("Output: %.20f"%output[8,0])
# Out:
# inference time: 0.06450390815734863
# Output: -0.21330091357231140137

# %%
# Test TRT optimized saved model
saved_model = tf.saved_model.load(os.path.join(export_path, "rt")) # normal saved model


image, _ = next(validation_generator)

import time
output = saved_model(image.astype(np.float32)) # load once to get more accurate representation of speed
start = time.time()
output = saved_model(image.astype(np.float32))
stop = time.time()
print("inference time: " + str(stop - start))
print("Output: %.20f"%output[8,0])
# Out:
# inference time: 0.0611567497253418
# Output: -0.13906964659690856934

# %%
# Run many samples through and save distribution 
validation_generator = batch_generator(data_directory, test_x, test_y, 32, False)
test = []
for i in range(50):
    img, _ = next(validation_generator)
    test.append(saved_model(img.astype(np.float32))[0][0])
    print(str(i), end="\r")
sns.distplot(test)
# Out:
# 49
